# %%
import pytest
import unittest
from modules.predict import predict_sentiment, predict_sarcasm

def test_predict_sentiment():
    text = "I love this movie!"
    sentiment = predict_sentiment(text)
    assert sentiment in ["positive", "negative", "neutral"]

def test_predict_sarcasm():
    text = "Oh, that's just what I needed!"
    sarcasm = predict_sarcasm(text)
    assert sarcasm in ["sarcastic", "non-sarcastic"]
