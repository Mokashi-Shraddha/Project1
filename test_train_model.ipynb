# %%
'''
import pytest
import unittest
from modules.train_model import train_sentiment_model, train_sarcasm_model

def test_load_sentiment_model():
    sentiment_model = train_sentiment_model()
    assert sentiment_model is not None

def test_load_sarcasm_model():
    sarcasm_model = train_sarcasm_model()
    assert sarcasm_model is not None
'''
# Out:
# '\nimport pytest\nimport unittest\nfrom modules.train_model import train_sentiment_model, train_sarcasm_model\n\ndef test_load_sentiment_model():\n    sentiment_model = train_sentiment_model()\n    assert sentiment_model is not None\n\ndef test_load_sarcasm_model():\n    sarcasm_model = train_sarcasm_model()\n    assert sarcasm_model is not None\n'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Colab Notebooks/project/modules
# Out:
# /content/drive/My Drive/Colab Notebooks/project/modules

# %%
import unittest
from modules.train_model import train_sentiment_model, train_sarcasm_model
class test_train_model(unittest.TestCase):
  def test_load_sentiment_model():
      sentiment_model = train_sentiment_model()
      assert sentiment_model is not None

  def test_load_sarcasm_model():
      sarcasm_model = train_sarcasm_model()
      assert sarcasm_model is not None

if __name__ == '__main__':
    unittest.main()
