# %%
'''
from google.colab import drive

def mount_google_drive():
    drive.mount('/content/drive')

# Mount Google Drive before accessing any files
mount_google_drive()

# Now you can access files in Google Drive
with open('/content/drive/My Drive/Colab Notebooks/project/modules/preprocessing.ipynb', 'r') as file:
    data = file.read()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pytest
import unittest
from modules.preprocessing import preprocess_text

def test_preprocess_text():
    text = "Hello, this is a test text!"
    processed_text = preprocess_text(text)
    assert processed_text == "hello test text"
